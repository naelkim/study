# %%
#pip install -U finance-datareader
# Out:
# ...
#   Using cached finance_datareader-0.9.6-py3-none-any.whl (17 kB)
# ...
#   Using cached requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import FinanceDataReader as fdr

# %%
KRX = fdr.StockListing('KRX')
KRX.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
Symbol = KOSPI['Symbol']
Name = KOSPI['Name']

# %%
target = [ i for i in zip(Symbol,Name)]
target[:10]
# Out:
# [('095570', 'AJ네트웍스'),
#  ('006840', 'AK홀딩스'),
#  ('027410', 'BGF'),
#  ('282330', 'BGF리테일'),
#  ('138930', 'BNK금융지주'),
#  ('001460', 'BYC'),
#  ('001465', 'BYC우'),
#  ('001040', 'CJ'),
#  ('079160', 'CJ CGV'),
#  ('00104K', 'CJ4우(전환)')]

# %%
df = fdr.DataReader(,'2017')
df['Close'].plot()
# Out:
#   File "<ipython-input-7-23c0fd33b2a7>", line 1
#     df = fdr.DataReader(,'2017')
#                         ^
# SyntaxError: invalid syntax

# %%
base_url = 'https://finance.naver.com/sise/theme.nhn?'
page_Num = range(1,7)
res = requests.get(base_url + '&page=' + str(page_Num))
res
# Out:
# <Response [200]>

# %%
# Out:
# 40

# %%
html = res.text
soup = BeautifulSoup(html, 'html.parser')
a = soup.select('div > #contentarea_left > table > tr > td.col_type1')
name = []
for i in page_Num:
    title = a[i].get_text().strip()
    name.append(title)

# %%
name
# Out:
# ['화폐/금융자동화기기',
#  '자전거',
#  '아스콘(아스팔트 콘크리트)',
#  '강관업체(Steel pipe)',
#  '해운',
#  'LPG(액화석유가스)']

# %%
html = res.text
soup = BeautifulSoup(html, 'html.parser')
a = soup.select('div > #contentarea_left > table > tr > td > number col_type2')
a
# Out:
# []

# %%
html = res.text
soup = BeautifulSoup(html, 'html.parser')
a = soup.select('div > #contentarea_left > table > tr > td > .number col_type2')
value = []
for i in range(0,79):
    title = a[i].get_text().strip()
    value.append(title)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-af6d487446aa> in <module>
#       4 value = []
#       5 for i in range(0,79):
# ----> 6     title = a[i].get_text().strip()
#       7     value.append(title)
#
# IndexError: list index out of range

# %%
a = soup.select('#contentarea_left > table > tr > td.col_type2 > span ')
a
# Out:
# [<span class="tah p11 red01">
#  				+3.93%
#  				</span>,
#  <span class="tah p11 red01">
#  				+3.27%
#  				</span>,
#  <span class="tah p11 red01">
#  				+2.06%
#  				</span>,
#  <span class="tah p11 red01">
#  				+1.69%
#  				</span>,
#  <span class="tah p11 red01">
#  				+1.62%
#  				</span>,
#  <span class="tah p11 red01">
#  				+1.26%
#  				</span>,
#  <span class="tah p11 red01">
#  				+1.24%
#  				</span>,
#  <span class="tah p11 red01">
#  				+0.45%
#  				</span>,
#  <span class="tah p11 red01">
#  				+0.41%
#  				</span>,
#  <span class="tah p11 red01">
#  				+0.35%
#  				</span>,
#  <span class="tah p11 red01">
#  				+0.27%
#  				</span>,
#  <span class="tah p11 nv01">
#  				-0.24%
#  				</span>,
#  <span class="tah p11 nv01">
#  				-0.80%
#  				</span>,
#  <span class="tah p11 nv01">
#  				-1.11%
#  				</span>,
#  <span class="tah p11 nv01">
#  				-1.25%
#  				</span>,
#  <span class="tah p11 nv01">
#  				-1.28%
#  				</span>,
# ...

# %%
name
# Out:
# ['메르스 코로나 바이러스',
#  '진원생명과..',
#  '웰크론',
#  '코로나19(진단/치료제/백신 개발 등)',
#  '필로시스헬..',
#  '우리들휴브..',
#  '구충제(펜벤다졸 등)',
#  '신풍제약',
#  '화일약품',
#  '보안주(물리)',
#  '피제이전자',
#  '데일리블록..',
#  '마스크',
#  '케이엠제약',
#  '웰크론',
#  '주류업(주정, 에탄올 등)',
#  'MH에탄올',
#  '창해에탄올',
#  '제약업체',
#  '신일제약',
#  '유나이티드..',
#  '유전자 치료제/분석',
#  '젠큐릭스',
#  '진원생명과..',
#  '줄기세포',
#  '우리들휴브..',
#  '코아스템',
#  '백신/진단시약/방역(신종플루, AI 등)',
#  '진원생명과..',
#  '신풍제약',
#  '2020 상반기 신규상장',
#  '젠큐릭스',
#  '서울바이오..',
#  '제4이동통신',
#  '바른테크놀..',
#  '쏠리드',
#  '일자리(취업)',
#  '메가엠디',
#  'DSC인베..',
#  '교육/온라인 교육',
#  '메가엠디',
#  'NE능률',
#  '재택근무/스마트워크',
#  '이씨에스',
#  '소프트캠프',
#  'NI(네트워크통합)',
#  '바른테크놀..',
#  '링네트',
#  '바이오시밀러(복제 바이오의약품)',
#  '종근당',
#  '한올바이오..',
#  'CCTV＆DVR',
#  '데일리블록..',
#  '뉴지랩',
#  '고령화 사회(노인복지)',
#  '피제이전자',
#  '대원제약',
#  'U-Healthcare(원격진료)',
#  '아스타',
#  '비트컴퓨터',
#  '치매',
#  '유유제약',
#  '모나리자',
#  '기업인수목적회사(SPAC)',
#  '소프트캠프',
#  '카이노스메..',
#  '면역항암제',
#  '유틸렉스',
#  '한올바이오..',
#  '도시가스',
#  '대성홀딩스',
#  '예스코홀딩..',
# ...

# %%
url = 'https://finance.naver.com/sise/investment_alert.nhn?type=warning'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
html = req.text
soup = BeautifulSoup(html, 'html.parser')
soup.select('#contentarea > div.box_type_l > table.type_2')
# Out:
# [<table cellpadding="0" cellspacing="0" class="type_2">
#  <table cellpadding="0" cellspacing="0" class="type_2" summary="투자 경고 종목 리스트">
#  <caption>투자경고종목</caption>
#  <col width="4%"/>
#  <col width="*"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="10%"/>
#  <col width="4%"/>
#  <tr class="align">
#  <th> </th>
#  <th>종목명</th>
#  <th class="number">현재가</th>
#  <th class="number">전일대비</th>
#  <th class="number">등락률</th>
#  <th class="number">거래량</th>
#  <th class="number">매도호가</th>
#  <th class="number">매수호가</th>
#  <th class="number">PER</th>
#  <th> </th>
#  </tr>
#  <tr><td class="blank_11" colspan="10"></td></tr>
#  <tr>
#  <td class="no">1</td>
#  <td><a class="tltle" href="/item/main.nhn?code=001067">JW중외제약2우B</a></td>
#  <td class="number">103,000</td>
#  <td class="number">
# ...
